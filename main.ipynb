# %%
import pandas as pd
from src.lib import (
    read_dataset,
    statistics,
    companysize,
    jobgrowth,
    requiredskill,
    # generate_pdf
)
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)

# %%
dataset_path = "../ai_job_market_insights.csv"
df = read_dataset(dataset_path)

# %%
statistics(df)
# Out:
#           Salary_USD
# count     500.000000
# mean    91222.390974
# std     20504.291453
# min     31969.526346
# 25%     78511.514863
# 50%     91998.195286
# 75%    103971.282092
# max    155209.821614

# %%
jobgrowth(df)
# Out:
# count        500
# unique         3
# top       Growth
# freq         169
# Name: Job_Growth_Projection, dtype: object

# %%
companysize(df)
# Out:
# count       500
# unique        3
# top       Small
# freq        171
# Name: Company_Size, dtype: object

# %%
requiredskill(df)
